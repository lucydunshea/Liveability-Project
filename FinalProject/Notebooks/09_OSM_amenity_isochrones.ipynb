# %% [markdown]
# # Isochrones for Melbourne and Christchurch

# %% [markdown]
# this note book uses the openrouteservice isochrones tool to get 400m walking distance for schools and supermarkets in christchurch and melbourne. To run this notebook, an Isochrones API key is required from https://openrouteservice.org/dev/#/home?tab=1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ipynb osmnx openrouteservice
# Out:
# Requirement already satisfied: ipynb in /usr/local/lib/python3.10/dist-packages (0.5.1)
# Requirement already satisfied: osmnx in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: openrouteservice in /usr/local/lib/python3.10/dist-packages (2.3.3)
# Requirement already satisfied: geopandas>=0.12 in /usr/local/lib/python3.10/dist-packages (from osmnx) (0.13.2)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.23.5)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.5.3)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (23.2)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2023.7.22)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (67.7.2)

# %%
import requests
import xml.etree.ElementTree as ET
import folium
import webbrowser
import time
import osmnx as ox
import geopandas as gpd
import openrouteservice.isochrones as ors
from os import path
from openrouteservice import client


# my API key:
api_key = '5b3ce3597851110001cf6248917c40c846744384a658cee39c9562d7'

# melb = 'City of Melbourne, Australia'
# melbourne = ox.geocode_to_gdf(melb)

# %%
# Melbourne city bounding box
bbox = [-37.850667, 144.896981,-37.775451, 144.991351]

url = f'https://overpass-api.de/api/interpreter?' \
      f'data=[out:json];' \
      f'(node["shop"="supermarket"]({",".join([str(x) for x in bbox])}););out;' \
      f'(way["shop"="supermarket"]({",".join([str(x) for x in bbox])}););out;' \
      f'(node["amenity"="school"]({",".join([str(x) for x in bbox])}););out;' \
      f'(way["amenity"="school"]({",".join([str(x) for x in bbox])}););out;' \
      f'>;' \
      f'out skel qt;'

r = requests.get(url)
melb_data = r.json()

# %%
# Create a dict to store all amenities of interest extracted from OSM
def get_data_subset(data):
  data_subset = {}

  for element in data['elements']:

      # Check that the element has a 'tags' dict and that the dict, if it exists, has the 'name' listed
      if 'tags' in element and 'name' in element['tags']:

          # If the element is a way, ie comprised of multiple nodes, then take the first node as the location
          if element['type'] == 'way':

              # for supermarkets, which are shops:
              if 'shop' in element['tags']:

                  data_subset[element['id']] = {
                  'amenity': element['tags']['shop']
                  , 'display name': element['tags']['name']
                  , 'type': 'way'
                  , 'location': element['nodes'][0]
              }

              # for hospitals and schools, which are amenities:
              elif 'amenity' in element['tags']:

                  data_subset[element['id']] = {
                  'amenity': element['tags']['amenity']
                  , 'display name': element['tags']['name']
                  , 'type': 'way'
                  , 'location': element['nodes'][0]
              }

            # If the element is a single node, store the location of the node
          elif element['type'] == 'node':

              # for supermarkets, which are shops:
              if 'shop' in element['tags']:

                  data_subset[element['id']] = {
                  'amenity': element['tags']['shop']
                  , 'display name': element['tags']['name']
                  , 'type': 'node'
                  , 'location': [element['lat'], element['lon']]
              }

              elif 'amenity' in element['tags']:

                  data_subset[element['id']] = {
                  'amenity': element['tags']['amenity']
                  , 'display name': element['tags']['name']
                  , 'type': 'node'
                  , 'location': [element['lat'], element['lon']]
              }

          else:
              print(f"Location {element['tags']['name']} does not appear to be readable")

  return data_subset

# %%
melb_data_subset = get_data_subset(melb_data)

# %%
# Extract the 'ways' from all amenities
def extract_way_locations(data_subset):
  way_nodes = [data_subset[key]['location'] for key in data_subset.keys() if data_subset[key]['type'] == 'way']

  way_locations = []

  # Query the API in batches of 100 nodes for speed.
  for i in range(0, len(way_nodes), 100):

      # Query the batch of nodes
      url = f"https://overpass-api.de/api/interpreter?" \
          f"node(id:{','.join(map(str, way_nodes[i:100 * (i + 1)]))});" \
          f"out;"
      r = requests.get(url)

      # XML tree output
      tree = ET.fromstring(r.text)
      way_locations.extend([x.attrib for x in tree.iter()][3:])
      return way_locations

# %%
melb_ways = extract_way_locations(melb_data_subset)

# %%
# function to get the ids of osm tags listed as ways
def get_way_ids(data_subset, way_locations):
  way_keys = [str(x['id']) for x in way_locations]  # Ensure all keys are strings

  # Assign the API response coordinates to the data
  for key in data_subset.keys():
      if data_subset[key]['type'] == 'way':
          location_str = str(data_subset[key]['location'])
          if location_str in way_keys:
              idx = way_keys.index(location_str)
              data_subset[key]['location'] = [way_locations[idx]['lat'], way_locations[idx]['lon']]
          else:
              # Handle the case where the location is not found in way_keys
              data_subset[key]['location'] = None  # or any other appropriate handling
  return data_subset

# %%
melb_data = get_way_ids(melb_data_subset, melb_ways)
# Out:
# {222420863: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.7889872, 144.9760904]},
#  302129542: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.7981407, 144.9683576]},
#  370224122: {'amenity': 'supermarket',
#   'display name': 'North Melbourne IGA X-press',
#   'type': 'node',
#   'location': [-37.798856, 144.953525]},
#  506153647: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.8205606, 144.9436054]},
#  573818021: {'amenity': 'supermarket',
#   'display name': 'McCoppins Food & Wine',
#   'type': 'node',
#   'location': [-37.7888604, 144.9895506]},
#  580722996: {'amenity': 'supermarket',
#   'display name': 'KimChi Korean Japanese Grocery',
#   'type': 'node',
#   'location': [-37.802712, 144.977554]},
#  591382457: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.8175611, 144.9649673]},
#  595501090: {'amenity': 'supermarket',
#   'display name': 'IGA X-press + Liquor',
#   'type': 'node',
#   'location': [-37.825805, 144.957017]},
#  595503060: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.8164808, 144.961159]},
#  613996660: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.811152, 144.965377]},
#  616602030: {'amenity': 'supermarket',
#   'display name': 'About Life',
#   'type': 'node',
#   'location': [-37.84107, 144.940275]},
#  619027750: {'amenity': 'supermarket',
#   'display name': 'Port Melbourne IGA',
#   'type': 'node',
#   'location': [-37.8418505, 144.9395728]},
#  634778556: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.8150986, 144.9554185]},
#  652307819: {'amenity': 'supermarket',
#   'display name': 'Sika Supermarket',
#   'type': 'node',
#   'location': [-37.8044181, 144.9772684]},
#  661600405: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.7871515, 144.92789]},
#  666846427: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.7758181, 144.9618499]},
#  666846439: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.7758523, 144.9626265]},
#  667225621: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.8147983, 144.9518038]},
#  670092371: {'amenity': 'supermarket',
#   'display name': 'Casa Iberica',
#   'type': 'node',
#   'location': [-37.7979262, 144.9759075]},
#  716358458: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.805942, 144.98017]},
#  726966377: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.809886, 144.971151]},
#  726967748: {'amenity': 'supermarket',
#   'display name': 'Woolworths Metro',
#   'type': 'node',
#   'location': [-37.810488, 144.97004]},
#  781006884: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.80314, 144.9490587]},
#  968355650: {'amenity': 'supermarket',
#   'display name': 'ALDI',
#   'type': 'node',
#   'location': [-37.8074444, 144.9621938]},
#  1009829808: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.8097374, 144.98563]},
#  1071936156: {'amenity': 'supermarket',
#   'display name': 'Hinoki Japanese Pantry',
#   'type': 'node',
#   'location': [-37.8005727, 144.983832]},
#  1071937924: {'amenity': 'supermarket',
#   'display name': 'Organic Wholefoods',
#   'type': 'node',
#   'location': [-37.800652, 144.983823]},
#  1072618063: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.7943305, 144.9298657]},
#  1104189986: {'amenity': 'supermarket',
#   'display name': 'The Source Bulk Foods',
#   'type': 'node',
#   'location': [-37.8028064, 144.9837684]},
#  1463468280: {'amenity': 'supermarket',
#   'display name': 'Aunt Maggies',
#   'type': 'node',
#   'location': [-37.806295, 144.981009]},
#  1668524726: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.8300256, 144.9693817]},
#  1778609934: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.7920177, 144.9193602]},
#  1937616038: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.7824892, 144.9148871]},
#  2010048473: {'amenity': 'supermarket',
#   'display name': 'IGA X-press plus Liquor',
#   'type': 'node',
#   'location': [-37.804482, 144.966104]},
#  2088105245: {'amenity': 'supermarket',
#   'display name': 'Woolworths Metro Clifton Hill',
#   'type': 'node',
#   'location': [-37.7888884, 144.9910691]},
#  2110023791: {'amenity': 'supermarket',
#   'display name': 'ALDI',
#   'type': 'node',
#   'location': [-37.829949, 144.9573832]},
#  2134206941: {'amenity': 'supermarket',
#   'display name': 'King & Godfree',
#   'type': 'node',
#   'location': [-37.798456, 144.967093]},
#  2140979575: {'amenity': 'supermarket',
#   'display name': 'Xin Fang Supermarket',
#   'type': 'node',
#   'location': [-37.808246, 144.955088]},
#  2148630815: {'amenity': 'supermarket',
#   'display name': 'Frootz on Parade',
#   'type': 'node',
#   'location': [-37.789079, 144.989017]},
#  2168228906: {'amenity': 'supermarket',
#   'display name': 'Sonsa Foods',
#   'type': 'node',
#   'location': [-37.8025305, 144.9838161]},
#  2184871393: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.8306564, 144.9573651]},
#  2233050619: {'amenity': 'supermarket',
#   'display name': 'Vegetable Connection',
#   'type': 'node',
#   'location': [-37.799665, 144.97808]},
#  2296783359: {'amenity': 'supermarket',
#   'display name': "Lin's Asian Grocery",
#   'type': 'node',
#   'location': [-37.806289, 144.96093]},
#  2296845056: {'amenity': 'supermarket',
#   'display name': 'Dae Bark Mart',
#   'type': 'node',
#   'location': [-37.818584, 144.963055]},
#  2341505826: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.8276939, 144.9665201]},
#  2345447317: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.7844714, 144.9381234]},
#  2372890188: {'amenity': 'supermarket',
#   'display name': 'The Dome Express',
#   'type': 'node',
#   'location': [-37.819346, 144.948342]},
#  2392307030: {'amenity': 'supermarket',
#   'display name': 'TT Mart',
#   'type': 'node',
#   'location': [-37.7788898, 144.9781392]},
#  2456364470: {'amenity': 'supermarket',
#   'display name': 'Tân Mỹ',
#   'type': 'node',
#   'location': [-37.799386, 144.8998]},
#  2487442399: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.802612, 144.978102]},
#  2599164407: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.7951171, 144.9415256]},
#  2713309468: {'amenity': 'supermarket',
#   'display name': 'Hometown Asian Supermarket',
#   'type': 'node',
#   'location': [-37.8085182, 144.9607589]},
#  2850428164: {'amenity': 'supermarket',
#   'display name': 'Crown Asian Supermarket',
#   'type': 'node',
#   'location': [-37.8147623, 144.9519191]},
#  3644340093: {'amenity': 'supermarket',
#   'display name': 'Tang Asian Grocery',
#   'type': 'node',
#   'location': [-37.812105, 144.96749]},
#  3800095557: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.803803, 144.983619]},
#  3840226142: {'amenity': 'supermarket',
#   'display name': 'Fitzroy IGA',
#   'type': 'node',
#   'location': [-37.794231, 144.9793382]},
#  3841977822: {'amenity': 'supermarket',
#   'display name': 'Crown Asian Supermarket',
#   'type': 'node',
#   'location': [-37.8097911, 144.960887]},
#  3928348515: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.784938, 144.9385839]},
#  3942998909: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.8013978, 144.897529]},
#  4677441389: {'amenity': 'supermarket',
#   'display name': 'Woolworths Metro',
#   'type': 'node',
#   'location': [-37.8095589, 144.9612274]},
#  4737562021: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.8224729, 144.9650768]},
#  4739288145: {'amenity': 'supermarket',
#   'display name': 'City Mart',
#   'type': 'node',
#   'location': [-37.8067075, 144.9600612]},
#  4935336424: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'node',
#   'location': [-37.8319294, 144.9609368]},
#  4965779821: {'amenity': 'supermarket',
#   'display name': 'Daiso Flinders',
#   'type': 'node',
#   'location': [-37.8179451, 144.9650971]},
#  5229563124: {'amenity': 'supermarket',
#   'display name': 'Woolworths Metro',
#   'type': 'node',
#   'location': [-37.8166713, 144.9645325]},
#  5548276451: {'amenity': 'supermarket',
#   'display name': 'Organic Wholefoods',
#   'type': 'node',
#   'location': [-37.783151, 144.9347807]},
#  5637523521: {'amenity': 'supermarket',
#   'display name': 'Woolworths Metro',
#   'type': 'node',
#   'location': [-37.8159063, 144.9560406]},
#  5793452696: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'node',
#   'location': [-37.7787245, 144.9764299]},
#  6033562243: {'amenity': 'supermarket',
#   'display name': 'KFL',
#   'type': 'node',
#   'location': [-37.7994862, 144.8985563]},
#  6547561972: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.7963605, 144.940678]},
#  6632403651: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.8210674, 144.9500958]},
#  6634574085: {'amenity': 'supermarket',
#   'display name': 'Coles Express',
#   'type': 'node',
#   'location': [-37.8099061, 144.963719]},
#  6699781948: {'amenity': 'supermarket',
#   'display name': 'Golden Express',
#   'type': 'node',
#   'location': [-37.8200723, 144.9424484]},
#  6699795743: {'amenity': 'supermarket',
#   'display name': 'Vic Harbour Grocery',
#   'type': 'node',
#   'location': [-37.819378, 144.9446863]},
#  6705227285: {'amenity': 'supermarket',
#   'display name': 'The Cruelty Free Shop Vegan Supermarket',
#   'type': 'node',
#   'location': [-37.798525, 144.9791097]},
#  6868706671: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.8120908, 144.9389849]},
#  7133185374: {'amenity': 'supermarket',
#   'display name': 'Carlton Supermarket',
#   'type': 'node',
#   'location': [-37.7926419, 144.9692514]},
#  7201833191: {'amenity': 'supermarket',
#   'display name': 'East West Marketplace',
#   'type': 'node',
#   'location': [-37.8126918, 144.9394133]},
#  7668307728: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'node',
#   'location': [-37.8240916, 144.9620137]},
#  8856663272: {'amenity': 'supermarket',
#   'display name': 'Ecopact Groceries',
#   'type': 'node',
#   'location': [-37.8029415, 144.8988455]},
#  8929808623: {'amenity': 'supermarket',
#   'display name': 'ALDI',
#   'type': 'node',
#   'location': [-37.7987035, 144.9836527]},
#  9869557343: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'node',
#   'location': [-37.82581, 144.9635577]},
#  10302027893: {'amenity': 'supermarket',
#   'display name': 'Tiem Tap Hoa Asian Grocer',
#   'type': 'node',
#   'location': [-37.7948464, 144.9415679]},
#  10576344803: {'amenity': 'supermarket',
#   'display name': 'Gum Tree Good Food',
#   'type': 'node',
#   'location': [-37.8388985, 144.9902376]},
#  10614020296: {'amenity': 'supermarket',
#   'display name': 'Woolworths Metro',
#   'type': 'node',
#   'location': [-37.8100673, 144.9587799]},
#  11020614156: {'amenity': 'supermarket',
#   'display name': 'Woolworth',
#   'type': 'node',
#   'location': [-37.8268359, 144.9592888]},
#  11104073377: {'amenity': 'supermarket',
#   'display name': 'Mr. Dad Super Market',
#   'type': 'node',
#   'location': [-37.8062642, 144.9617649]},
#  11168824374: {'amenity': 'supermarket',
#   'display name': 'Fawkner Express Grovery Store',
#   'type': 'node',
#   'location': [-37.8385464, 144.9769345]},
#  11182312635: {'amenity': 'supermarket',
#   'display name': 'IGA X-press',
#   'type': 'node',
#   'location': [-37.8176845, 144.9583477]},
#  27986149: {'amenity': 'supermarket',
#   'display name': 'KT Mart',
#   'type': 'way',
#   'location': ['-37.8042317', '144.9589297']},
#  32217294: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'way',
#   'location': ['-37.8016839', '144.9836896']},
#  38313264: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'way',
#   'location': ['-37.8316067', '144.9298411']},
#  53839901: {'amenity': 'supermarket',
#   'display name': 'Coles',
#   'type': 'way',
#   'location': ['-37.7981636', '144.9777803']},
#  196467084: {'amenity': 'supermarket',
#   'display name': "Piedimonte's Supa IGA plus Liquor",
#   'type': 'way',
#   'location': ['-37.7832861', '144.9827437']},
#  238620404: {'amenity': 'supermarket',
#   'display name': 'D&K',
#   'type': 'way',
#   'location': ['-37.7986374', '144.9008952']},
#  239074307: {'amenity': 'supermarket',
#   'display name': 'Thành Phát',
#   'type': 'way',
#   'location': ['-37.7997078', '144.9023338']},
#  314944030: {'amenity': 'supermarket',
#   'display name': 'ALDI',
#   'type': 'way',
#   'location': ['-37.8075205', '144.9485132']},
#  315126226: {'amenity': 'supermarket',
#   'display name': 'North Melbourne Supa IGA + Liquor',
#   'type': 'way',
#   'location': ['-37.8044784', '144.9495172']},
#  340065327: {'amenity': 'supermarket',
#   'display name': 'IGA',
#   'type': 'way',
#   'location': ['-37.8505103', '144.9644625']},
#  636550045: {'amenity': 'supermarket',
#   'display name': 'Western Halal Meat',
#   'type': 'way',
#   'location': ['-37.8011975', '144.9014056']},
#  636550046: {'amenity': 'supermarket',
#   'display name': 'Salaam Namasthe',
#   'type': 'way',
#   'location': ['-37.8010665', '144.9010799']},
#  636860757: {'amenity': 'supermarket',
#   'display name': 'Famous Halal Quality',
#   'type': 'way',
#   'location': ['-37.8006867', '144.8992911']},
#  732485948: {'amenity': 'supermarket',
#   'display name': 'KFL Asian Supermarket',
#   'type': 'way',
#   'location': ['-37.7883776', '144.9302274']},
#  732485980: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'way',
#   'location': ['-37.7878817', '144.9305167']},
#  732904918: {'amenity': 'supermarket',
#   'display name': 'Cheaper Buy Miles',
#   'type': 'way',
#   'location': ['-37.7883776', '144.9302274']},
#  826340453: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'way',
#   'location': ['-37.8475047', '144.9492004']},
#  836660881: {'amenity': 'supermarket',
#   'display name': 'Gumtree',
#   'type': 'way',
#   'location': ['-37.8412329', '144.9555253']},
#  837263906: {'amenity': 'supermarket',
#   'display name': 'Foodworks',
#   'type': 'way',
#   'location': ['-37.8413392', '144.9539439']},
#  902713937: {'amenity': 'supermarket',
#   'display name': 'Woolworths',
#   'type': 'way',
#   'location': ['-37.8188716', '144.9534479']},
#  1021887745: {'amenity': 'school',
#   'display name': 'Collingwood Alternative School',
#   'type': 'node',
#   'location': [-37.8023876, 144.9856479]},
#  4742935145: {'amenity': 'school',
#   'display name': 'Ozford College',
#   'type': 'node',
#   'location': [-37.8127971, 144.9544042]},
#  10057889116: {'amenity': 'school',
#   'display name': 'Travancore School Parkville Campus',
#   'type': 'node',
#   'location': [-37.7804607, 144.9477902]},
#  10057903017: {'amenity': 'school',
#   'display name': 'Parkville College',
#   'type': 'node',
#   'location': [-37.7781711, 144.9453118]},
#  10057903018: {'amenity': 'school',
#   'display name': 'River Nile School',
#   'type': 'node',
#   'location': [-37.8050784, 144.9549517]},
#  10057903019: {'amenity': 'school',
#   'display name': 'Holmes Grammar School',
#   'type': 'node',
#   'location': [-37.8103211, 144.9721869]},
#  5179319: {'amenity': 'school',
#   'display name': 'The University High School',
#   'type': 'way',
#   'location': ['-37.7972042', '144.9575110']},
#  5455679: {'amenity': 'school',
#   'display name': 'North Melbourne Primary School',
#   'type': 'way',
#   'location': ['-37.7980730', '144.9525317']},
#  5456099: {'amenity': 'school',
#   'display name': "Simonds Catholic College (St Mary's 7–10 Campus)",
#   'type': 'way',
#   'location': ['-37.8063273', '144.9522312']},
#  11207944: {'amenity': 'school',
#   'display name': 'Princes Hill Secondary College',
#   'type': 'way',
#   'location': ['-37.7825822', '144.9647118']},
#  12395079: {'amenity': 'school',
#   'display name': 'Merri Creek Primary School',
#   'type': 'way',
#   'location': ['-37.7764486', '144.9873555']},
#  18051619: {'amenity': 'school',
#   'display name': 'Middle Park Primary School',
#   'type': 'way',
#   'location': ['-37.8484913', '144.9574307']},
#  22780514: {'amenity': 'school',
#   'display name': 'Brunswick South Primary School',
#   'type': 'way',
#   'location': ['-37.7785163', '144.9716249']},
#  22987621: {'amenity': 'school',
#   'display name': 'Carlton North Primary School',
#   'type': 'way',
#   'location': ['-37.7906260', '144.9723968']},
#  23146917: {'amenity': 'school',
#   'display name': 'Flemington Primary School',
#   'type': 'way',
#   'location': ['-37.7799398', '144.9352419']},
#  23704337: {'amenity': 'school',
#   'display name': "Mac.Robertson Girls' High School",
#   'type': 'way',
#   'location': ['-37.8362216', '144.9727191']},
#  25758612: {'amenity': 'school',
#   'display name': 'Kensington Community High School',
#   'type': 'way',
#   'location': ['-37.7880110', '144.9266818']},
#  26115342: {'amenity': 'school',
#   'display name': 'Ascot Vale West Primary School',
#   'type': 'way',
#   'location': ['-37.7800962', '144.9101245']},
#  27480317: {'amenity': 'school',
#   'display name': 'Academy of Mary Immaculate',
#   'type': 'way',
#   'location': ['-37.8040561', '144.9740107']},
#  27521869: {'amenity': 'school',
#   'display name': 'Carlton Primary School',
#   'type': 'way',
#   'location': ['-37.7960251', '144.9694222']},
#  27550692: {'amenity': 'school',
#   'display name': 'Albert Park Primary School',
#   'type': 'way',
#   'location': ['-37.8425395', '144.9523473']},
#  27557213: {'amenity': 'school',
#   'display name': 'South Yarra Primary School',
#   'type': 'way',
#   'location': ['-37.8409946', '144.9858599']},
#  27557257: {'amenity': 'school',
#   'display name': 'Christ Church Grammar School',
#   'type': 'way',
#   'location': ['-37.8391847', '144.9852967']},
#  27696178: {'amenity': 'school',
#   'display name': 'Melbourne Girls Grammar School',
#   'type': 'way',
#   'location': ['-37.8326757', '144.9858109']},
#  27943602: {'amenity': 'school',
#   'display name': "St Aloysius Girls' College",
#   'type': 'way',
#   'location': ['-37.7923440', '144.9424347']},
#  27943719: {'amenity': 'school',
#   'display name': "St Joseph's Flexible Learning Centre",
#   'type': 'way',
#   'location': ['-37.8037340', '144.9544914']},
#  29122750: {'amenity': 'school',
#   'display name': 'Our Lady Help of Christians Primary School',
#   'type': 'way',
#   'location': ['-37.7773308', '144.9784274']},
#  30066634: {'amenity': 'school',
#   'display name': 'Carlton Gardens Primary School',
#   'type': 'way',
#   'location': ['-37.8022553', '144.9695119']},
#  30639265: {'amenity': 'school',
#   'display name': 'Port Melbourne Primary School',
#   'type': 'way',
#   'location': ['-37.8364144', '144.9322186']},
#  30810054: {'amenity': 'school',
#   'display name': 'Port Phillip Specialist School',
#   'type': 'way',
#   'location': ['-37.8373311', '144.9415782']},
#  32217275: {'amenity': 'school',
#   'display name': 'Sacred Heart Primary School',
#   'type': 'way',
#   'location': ['-37.8023124', '144.9788888']},
#  32247131: {'amenity': 'school',
#   'display name': "St Joseph's Primary School",
#   'type': 'way',
#   'location': ['-37.8004684', '144.9870095']},
#  32325369: {'amenity': 'school',
#   'display name': 'Collingwood College',
#   'type': 'way',
#   'location': ['-37.8031692', '144.9891594']},
#  32893648: {'amenity': 'school',
#   'display name': "St John's Primary School",
#   'type': 'way',
#   'location': ['-37.7908073', '144.9881011']},
#  32920772: {'amenity': 'school',
#   'display name': "St Monica's Primary School",
#   'type': 'way',
#   'location': ['-37.8014730', '144.9073992']},
#  33297926: {'amenity': 'school',
#   'display name': 'Holy Rosary Primary School',
#   'type': 'way',
#   'location': ['-37.7959319', '144.9287992']},
#  33297970: {'amenity': 'school',
#   'display name': 'Kensington Primary School',
#   'type': 'way',
#   'location': ['-37.7926138', '144.9263973']},
#  33657115: {'amenity': 'school',
#   'display name': 'Ascot Vale Heights School',
#   'type': 'way',
#   'location': ['-37.7763150', '144.9323004']},
#  34988416: {'amenity': 'school',
#   'display name': 'Princes Hill Primary School',
#   'type': 'way',
#   'location': ['-37.7812501', '144.9672850']},
#  38099072: {'amenity': 'school',
#   'display name': 'Fitzroy High School',
#   'type': 'way',
#   'location': ['-37.7853109', '144.9885571']},
#  39022621: {'amenity': 'school',
#   'display name': "St Michael's Primary School",
#   'type': 'way',
#   'location': ['-37.7936563', '144.9459597']},
#  41411167: {'amenity': 'school',
#   'display name': 'Debney Meadows Primary School',
#   'type': 'way',
#   'location': ['-37.7864086', '144.9353484']},
#  43929688: {'amenity': 'school',
#   'display name': 'Fitzroy North Primary School',
#   'type': 'way',
#   'location': ['-37.7852470', '144.9830984']},
#  44075286: {'amenity': 'school',
#   'display name': 'Montague School',
#   'type': 'way',
#   'location': ['-37.8311744', '144.9497924']},
#  44666624: {'amenity': 'school',
#   'display name': 'Albert Park College',
#   'type': 'way',
#   'location': ['-37.8453320', '144.9482556']},
#  49130602: {'amenity': 'school',
#   'display name': 'Footscray City Primary School',
#   'type': 'way',
#   'location': ['-37.8053057', '144.8995041']},
#  52008366: {'amenity': 'school',
#   'display name': 'Victorian College of the Arts Secondary School',
#   'type': 'way',
#   'location': ['-37.8287251', '144.9648171']},
#  120427698: {'amenity': 'school',
#   'display name': 'Melbourne Girls Grammar School Morris Hall Campus',
#   'type': 'way',
#   'location': ['-37.8356691', '144.9886879']},
#  129727118: {'amenity': 'school',
#   'display name': 'Collingwood English Language School',
#   'type': 'way',
#   'location': ['-37.8079763', '144.9848520']},
#  149984271: {'amenity': 'school',
#   'display name': 'Deutsche Schule Melbourne',
#   'type': 'way',
#   'location': ['-37.7786236', '144.9826088']},
#  175516621: {'amenity': 'school',
#   'display name': 'Mount Alexander College',
#   'type': 'way',
#   'location': ['-37.7817384', '144.9328385']},
#  207259771: {'amenity': 'school',
#   'display name': 'Victorian College for the Deaf',
#   'type': 'way',
#   'location': ['-37.8490086', '144.9805507']},
#  207259774: {'amenity': 'school',
#   'display name': 'Wesley College St Kilda Road Campus',
#   'type': 'way',
#   'location': ['-37.8478874', '144.9801891']},
#  371316190: {'amenity': 'school',
#   'display name': 'Port Melbourne Secondary College',
#   'type': 'way',
#   'location': ['-37.8315899', '144.9313288']},
#  380698334: {'amenity': 'school',
#   'display name': 'The University High School Elizabeth Blackburn School of Sciences',
#   'type': 'way',
#   'location': ['-37.7968418', '144.9542426']},
#  383369889: {'amenity': 'school',
#   'display name': "St Brendan's Primary School",
#   'type': 'way',
#   'location': ['-37.7843266', '144.9314163']},
#  456564697: {'amenity': 'school',
#   'display name': 'Wurun Senior Campus',
#   'type': 'way',
#   'location': ['-37.7926519', '144.9842185']},
#  511192823: {'amenity': 'school',
#   'display name': 'Haileybury College City Campus',
#   'type': 'way',
#   'location': ['-37.8113644', '144.9532232']},
#  512468573: {'amenity': 'school',
#   'display name': 'Footscray High School Pilgrim Campus',
#   'type': 'way',
#   'location': ['-37.8065117', '144.8970867']},
#  544054769: {'amenity': 'school',
#   'display name': 'South Melbourne Primary School',
#   'type': 'way',
#   'location': ['-37.8290811', '144.9533007']},
#  583831723: {'amenity': 'school',
#   'display name': "Simonds Catholic College St Brigid's VCE Campus",
#   'type': 'way',
#   'location': ['-37.7926559', '144.9759518']},
#  1029438753: {'amenity': 'school',
#   'display name': 'South Melbourne Park Primary School',
#   'type': 'way',
#   'location': ['-37.8406300', '144.9622187']},
#  1098469953: {'amenity': 'school',
#   'display name': 'Docklands Primary School',
#   'type': 'way',
#   'location': ['-37.8127411', '144.9404061']},
#  1115866861: {'amenity': 'school',
#   'display name': 'Galilee Regional Catholic Primary School',
#   'type': 'way',
#   'location': ['-37.8365661', '144.9551916']},
#  1134443340: {'amenity': 'school',
#   'display name': 'Fitzroy Community School',
#   'type': 'way',
#   'location': ['-37.7891139', '144.9796281']}}

# %%
# Generate the API parameters. using networks that are acessible by foot according to OSM
# Range of distance to match ideal walkind distances according to literature
params = {
    'profile': 'foot-walking'
    , 'range_type': 'distance'
    , 'range': [800]  #  800 m isochrones
}

# Throttling requests to ensure API is not overloaded
throttle_requests = True

# %%
def make_isochrones(data_subset, api_key, params):
# The API key is entered at the top of this notebook
  ors = client.Client(key=api_key)

  # Loop over the amentites and query the API for the isochrone data, then add each amenity to the map
  for key in data_subset.keys():

      # sleep every three seconds to ensure query parameters are not exceeded (limit 20 per minute)
      if throttle_requests:
          time.sleep(3)

      # Add amenity coordinates to params and query ORS.
      params['locations'] = [list(reversed(data_subset[key]['location']))]
      data_subset[key]['isochrone'] = ors.isochrones(**params)
  return data_subset

# %%
#@title The following block of code is computationally expensive, and requires an API key to run. To save time, the melbourne amenity isochrones have been saved as .pkl file in the data section of this folder.

# %%
# UNCOMMENT TO RUN
# melb_isochrones = make_isochrones(melb_data, api_key, params)

# %%
# save isochrone data subset as an object
import pickle

with open('/content/drive/MyDrive/FinalProject/Data/amenity-isochrones/melbourne_amenity_isochrones.pkl', 'wb') as f:
    pickle.dump(melb_isochrones, f)

# %%
# Layer Groups
def map_amenities(data_subset, m):
  sch_layer = folium.FeatureGroup(name='Schools')
  sup_layer = folium.FeatureGroup(name='Supermarkets')
  for key in data_subset.keys():

      if 'isochrone' in data_subset[key] and data_subset[key]['amenity'] == 'supermarket':
      # Add isochrone to the map
          folium.features.GeoJson(
              data=data_subset[key]['isochrone']
              , style_function=lambda feature: dict(color='#2C7329')
          ).add_to(sup_layer)

      elif 'isochrone' in data_subset[key] and data_subset[key]['amenity'] == 'school':
      # Add isochrone to the map
          folium.features.GeoJson(
              data=data_subset[key]['isochrone']
              , style_function=lambda feature: dict(color='#3171AE')
          ).add_to(sch_layer)

      else:
          continue
  sch_layer.add_to(m)
  sup_layer.add_to(m)
  return m #sch_layer, sup_layer





# m.save('Amenities_melbourne.html')
# webbrowser.open(path.realpath('Amenities_melbourne.html'), new=2)

# %%
import matplotlib.pyplot as plt
import folium
import branca.colormap as cm

# function to produce a map of greenspace and their values

def greenspace_map(gdf, latitude, longitude, col_name):
    try:
        m = folium.Map(location=[latitude, longitude], zoom_start=12, tiles='cartodb positron')
        gdf.explore(gdf[col_name],
                    cmap=['#5c6b28','#7c9d45','#a47e4f'],
                    tooltip=col_name,
                    m=m,
                    popup=f"{gdf['park_name']}"
                f" Average NDVI value: {gdf['median_NDVI']}",
                    categorical=True)

        return m
    except Exception as e:
        return str(e)

# %%
chc = 'Christchurch, New Zealand'
christchurch = ox.geocode_to_gdf(chc)
christchurch.bounds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ba99a60adb3f> in <cell line: 2>()
#       1 chc = 'Christchurch, New Zealand'
# ----> 2 christchurch = ox.geocode_to_gdf(chc)
#       3 christchurch.bounds
#
# NameError: name 'ox' is not defined

# %%
# Christchurch city bounding box
bbox = [-43.629201, 172.393025, -43.389087, 172.821627]

url = f'https://overpass-api.de/api/interpreter?' \
      f'data=[out:json];' \
      f'(node["shop"="supermarket"]({",".join([str(x) for x in bbox])}););out;' \
      f'(way["shop"="supermarket"]({",".join([str(x) for x in bbox])}););out;' \
      f'(node["amenity"="school"]({",".join([str(x) for x in bbox])}););out;' \
      f'(way["amenity"="school"]({",".join([str(x) for x in bbox])}););out;' \
      f'>;' \
      f'out skel qt;'

r = requests.get(url)
chc_data = r.json()

# %%
chc_data_subset = get_data_subset(chc_data)
chc_ways = extract_way_locations(chc_data_subset)
chc_data_subset = get_way_ids(chc_data_subset, chc_ways)

# %%
# Removing keys from the data where no location is tagged
keys_to_remove = []

# Loop through the dictionary and identify keys to remove
for key, value in chc_data_subset.items():
    if 'location' in value and value['location'] == 'none':
        keys_to_remove.append(key)

# Remove the identified keys
for key in keys_to_remove:
    del chc_data_subset[key]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-11c67c85f18a> in <cell line: 5>()
#       3
#       4 # Loop through the dictionary and identify keys to remove
# ----> 5 for key, value in chc_data_subset.items():
#       6     if 'location' in value and value['location'] == 'none':
#       7         keys_to_remove.append(key)
#
# NameError: name 'chc_data_subset' is not defined

# %%
chch_isochrones = make_isochrones(chc_data_subset, api_key, params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-c002c54b8e8f> in <cell line: 1>()
# ----> 1 chch_isochrones = make_isochrones(chc_data_subset, api_key, params)
#
# <ipython-input-21-66bdc39e9ffe> in make_isochrones(data_subset, api_key, params)
#      12
#      13       # Add supermarket coordinates to params and query ORS.
# ---> 14       params['locations'] = [list(reversed(data_subset[key]['location']))]
#      15       data_subset[key]['isochrone'] = ors.isochrones(**params)
#      16   return data_subset
#
# TypeError: 'NoneType' object is not reversible

# %%
# save isochrone data subset as an object
import pickle

with open('/content/drive/MyDrive/FinalProject/Data/amenity-isochrones/christchurch_amenity_isochrones.pkl', 'wb') as f:
    pickle.dump(chc_data_subset, f)
